# %%
# !git clone https://github.com/sooo66/semeval2026-task12-dataset.git
# Out:
# Cloning into 'semeval2026-task12-dataset'...
# remote: Enumerating objects: 69, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 69 (delta 30), reused 51 (delta 15), pack-reused 0 (from 0)
# Receiving objects: 100% (69/69), 6.72 MiB | 19.48 MiB/s, done.
# Resolving deltas: 100% (30/30), done.

# %%
import json
import re

def clean_text(text):
    """
    پاک‌سازی اولیه متون
    """
    if not text or not isinstance(text, str):
        return ""
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

def load_and_merge_data(questions_path, docs_path):
    # ۱. خواندن فایل اسناد (docs.json)
    with open(docs_path, 'r', encoding='utf-8') as f:
        docs_raw = json.load(f)
        
    # ۲. تبدیل هوشمند لیست به دیکشنری برای جستجوی سریع بر اساس topic_id
    docs_dict = {}
    
    # بررسی می‌کنیم که آیا فایل اصلی لیستی از آیتم‌هاست
    if isinstance(docs_raw, list):
        for item in docs_raw:
            if not isinstance(item, dict):
                continue
                
            t_id = item.get("topic_id")
            if not t_id:
                continue
                
            if t_id not in docs_dict:
                docs_dict[t_id] = []
                
            # حالت اول: اگر آیتم شامل لیستی از اسناد در کلید docs باشد
            if "docs" in item or "documents" in item:
                inner_docs = item.get("docs", item.get("documents", []))
                for d in inner_docs:
                    if isinstance(d, dict):
                        # استخراج متن از دیکشنری داخلی
                        text_val = d.get("text", d.get("content", d.get("doc", "")))
                        docs_dict[t_id].append(text_val)
                    elif isinstance(d, str):
                        docs_dict[t_id].append(d)
            # حالت دوم: اگر خود آیتم مستقیماً یک سند باشد
            else:
                text_val = item.get("text", item.get("content", item.get("doc", "")))
                if text_val:
                    docs_dict[t_id].append(text_val)

    merged_dataset = []
    
    # ۳. خواندن فایل سوالات و اتصال به اسناد
    with open(questions_path, 'r', encoding='utf-8') as f:
        for line in f:
            if not line.strip():
                continue
                
            question_item = json.loads(line.strip())
            topic_id = question_item.get("topic_id")
            
            # استخراج اسناد از دیکشنری که بالاتر ساختیم (این بار بدون خطا)
            related_docs = docs_dict.get(topic_id, [])
            
            # پاک‌سازی و ترکیب متون
            cleaned_docs = [clean_text(doc) for doc in related_docs if doc]
            context_text = " ".join(cleaned_docs)
            
            # ۴. ساختار نهایی
            merged_item = {
                "id": question_item.get("id"),
                "topic_id": topic_id,
                "target_event": clean_text(question_item.get("target_event")),
                "options": {
                    "A": clean_text(question_item.get("option_A")),
                    "B": clean_text(question_item.get("option_B")),
                    "C": clean_text(question_item.get("option_C")),
                    "D": clean_text(question_item.get("option_D"))
                },
                "golden_answer": question_item.get("golden_answer"),
                "context": context_text 
            }
            merged_dataset.append(merged_item)
            
    return merged_dataset

# ==========================================
# اجرای کد
# ==========================================

QUESTIONS_FILE = 'semeval2026-task12-dataset/dev_data/questions.jsonl'
DOCS_FILE = 'semeval2026-task12-dataset/dev_data/docs.json'

dataset = load_and_merge_data(QUESTIONS_FILE, DOCS_FILE)

if dataset:
    print("✅ پردازش با موفقیت انجام شد!\n")
    print(f"🔹 رویداد هدف: {dataset[0]['target_event']}")
    print(f"🔹 گزینه‌ها:")
    for key, val in dataset[0]['options'].items():
        print(f"   {key}: {val}")
    print(f"🔹 پاسخ درست: {dataset[0]['golden_answer']}")
    print(f"🔹 طول متن زمینه (Context): {len(dataset[0]['context'])} کاراکتر")
else:
    print("مجموعه داده خالی است!")
# Out:
# ✅ پردازش با موفقیت انجام شد!
#
# 🔹 رویداد هدف: President Yoon Suk Yeol vowed to carry out a thorough investigation.
# 🔹 گزینه‌ها:
#    A: Kim and her friend crawled out of the crush and were pulled into a tavern by adults.
#    B: Emergency workers and pedestrians performed CPR on victims in the streets on Saturday night.
#    C: At least 153 people were killed and dozens injured.
#    D: Kim and her friend entered the alley at 8 p.m. and became trapped as the crowd density increased.
# 🔹 پاسخ درست: C
# 🔹 طول متن زمینه (Context): 86730 کاراکتر

# %%
# در صورت نیاز کتابخانه‌های زیر را نصب کنید:
# !pip install transformers torch scikit-learn sentence-transformers peft

import json
import re
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
from peft import PeftModel
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# ==========================================
# ۰. بارگذاری مدل تعبیه‌سازی (Embedding) برای جستجوی معنایی
# ==========================================
print("در حال بارگذاری مدل Embedding (برای RAG معنایی)...")
embedder = SentenceTransformer('all-MiniLM-L6-v2') 

# ==========================================
# ۱. تابع بازیابی اطلاعات (Semantic RAG) برای فیلتر کانتکست
# ==========================================
def retrieve_relevant_context(sample, top_k=5):
    context = sample['context']
    
    sentences = re.split(r'(?<=[.!?])\s+', context)
    sentences = [s.strip() for s in sentences if len(s.strip()) > 20]
    
    if not sentences:
        return ""

    query = sample['target_event'] + " " + " ".join(sample['options'].values())

    sentence_embeddings = embedder.encode(sentences)
    query_embedding = embedder.encode([query])

    similarities = cosine_similarity(query_embedding, sentence_embeddings).flatten()
    
    top_indices = similarities.argsort()[-top_k:]
    top_indices_sorted = sorted(top_indices) 
    
    best_sentences = [sentences[i] for i in top_indices_sorted]
    return " ".join(best_sentences)

# ==========================================
# ۲. تابع ساخت پیام‌ها (دقیقاً مطابق با فرمت زمان آموزش)
# ==========================================
def generate_messages(sample, filtered_context):
    # پرامپت‌ها باید دقیقاً شبیه زمان فاین‌تیونینگ باشند
    messages = [
        {
            "role": "system", 
            "content": "You are an expert AI specialized in Abductive Event Reasoning. First, briefly reason based on the provided Context. Then, output the uppercase letter(s) of the correct option(s) inside <ANSWER> tags."
        },
        {
            "role": "user", 
            "content": f"Context: {filtered_context}\n\nTarget Event: {sample['target_event']}\n\nOptions:\nA) {sample['options']['A']}\nB) {sample['options']['B']}\nC) {sample['options']['C']}\nD) {sample['options']['D']}\n\nReason and output final answer in <ANSWER> tags."
        }
    ]
    return messages

# ==========================================
# ۳. بارگذاری مدل فاین‌تیون شده (Base Model + LoRA Adapter)
# ==========================================
print("\nدر حال بارگذاری مدل زبانی...")
BASE_MODEL_ID = "Qwen/Qwen2.5-7B-Instruct"
ADAPTER_PATH = "/kaggle/input/datasets/daniyalghoreyshi/qwen-ft-semeval/qwen-abductive-final-adapter" # مسیر پوشه آداپتور شما

# بارگذاری توکنایزر
tokenizer = AutoTokenizer.from_pretrained(ADAPTER_PATH)

# بارگذاری مدل پایه
base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL_ID,
    device_map="auto",
    torch_dtype=torch.float16 
)

# چسباندن وزن‌های فاین‌تیون شده (آداپتور) به مدل پایه
model = PeftModel.from_pretrained(base_model, ADAPTER_PATH)

# ساخت پایپ‌لاین با مدل ترکیب شده
pipe = pipeline(
    "text-generation", 
    model=model, 
    tokenizer=tokenizer,
    device_map="auto",
    torch_dtype=torch.float16,
    return_full_text=False # این تنظیم باعث می‌شود پرامپت اولیه در خروجی تکرار نشود و متن تمیزتری بگیریم
)
print("✅ مدل فاین‌تیون شده با موفقیت بارگذاری شد.\n")

# فرض می‌کنیم متغیر dataset از اجرای گام‌های قبلی موجود است
# برای تست یک نمونه:
sample_data = dataset[0]

smart_context = retrieve_relevant_context(sample_data, top_k=5)
messages = generate_messages(sample_data, smart_context)
formatted_prompt = pipe.tokenizer.apply_chat_template(
    messages, 
    tokenize=False, 
    add_generation_prompt=True
)

print("\nدر حال تولید پاسخ نمونه...")
response = pipe(
    formatted_prompt, 
    max_new_tokens=200, 
    temperature=0.1, 
    do_sample=False, # در مدل‌های فاین‌تیون شده بهتر است do_sample خاموش باشد تا دقیق‌ترین جواب را بدهد
    pad_token_id=pipe.tokenizer.eos_token_id
)

# چون return_full_text=False قرار دادیم، خروجی فقط شامل متن جدید است
raw_answer = response[0]['generated_text'].strip()

# استخراج هوشمندانه از داخل تگ <ANSWER>
match = re.search(r'<ANSWER>\s*([A-D](?:\s*,\s*[A-D])*)\s*</ANSWER>', raw_answer)
if match:
    clean_answer = match.group(1).replace(' ', '')
else:
    fallback_match = re.search(r'[A-D](?:\s*,\s*[A-D])*', raw_answer)
    clean_answer = fallback_match.group(0).replace(' ', '') if fallback_match else "نامشخص"

print("-" * 50)
print(f"🧠 استدلال تولید شده توسط مدل:\n{raw_answer}")
print("-" * 50)
print(f"✨ خروجی نهایی و استخراج شده: {clean_answer}")
print(f"🎯 پاسخ درست (Golden Answer): {sample_data['golden_answer']}")
# Out:
# در حال بارگذاری مدل Embedding (برای RAG معنایی)...
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# در حال بارگذاری مدل زبانی...
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# ✅ مدل فاین‌تیون شده با موفقیت بارگذاری شد.
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Passing `generation_config` together with generation-related arguments=({'temperature', 'do_sample', 'max_new_tokens', 'pad_token_id'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# در حال تولید پاسخ نمونه...
# --------------------------------------------------
# 🧠 استدلال تولید شده توسط مدل:
# The event "At least 153 people were killed and dozens injured" is the direct cause of President Yoon Suk Yeol's vow to carry out a thorough investigation because the severity of the crowd crush disaster necessitated a comprehensive review to understand the circumstances leading to the tragedy. The high number of casualties and injuries would likely prompt the government to take swift action to prevent similar incidents in the future. This response is a logical consequence of the devastating event.
# <ANSWER>C</ANSWER>
# --------------------------------------------------
# ✨ خروجی نهایی و استخراج شده: C
# 🎯 پاسخ درست (Golden Answer): C

# %%
import json
import re
from tqdm import tqdm

# ==========================================
# تابع ارزیابی
# ==========================================
def calculate_score(predicted_answers_str, golden_answers_str):
    if predicted_answers_str == "نامشخص":
        return 0.0
        
    P = set([ans.strip() for ans in predicted_answers_str.split(',') if ans.strip()])
    G = set([ans.strip() for ans in golden_answers_str.split(',') if ans.strip()])
    
    if P == G and len(P) > 0:
        return 1.0  
    elif P.issubset(G) and len(P) > 0:
        return 0.5  
    else:
        return 0.0  

# ==========================================
# ارزیابی کلی روی کل دیتاست (با مدل فاین‌تیون شده)
# ==========================================
print(f"\nشروع ارزیابی روی {len(dataset)} نمونه...")
total_score = 0
results_log = []

for index, sample in enumerate(tqdm(dataset, desc="Processing Samples")):
    
    # ۱. استخراج کانتکست معنایی
    smart_context = retrieve_relevant_context(sample, top_k=5)
    
    # ۲. ساخت پرامپت مطابق با آموزش
    messages = generate_messages(sample, smart_context)
    formatted_prompt = pipe.tokenizer.apply_chat_template(
        messages, tokenize=False, add_generation_prompt=True
    )
    
    # ۳. تولید خروجی
    response = pipe(
        formatted_prompt, 
        max_new_tokens=200, 
        temperature=0.1, 
        do_sample=False, # مدل فاین‌تیون شده با do_sample=False (Greedy Decoding) پایدارتر عمل می‌کند
        pad_token_id=pipe.tokenizer.eos_token_id
    )
    
    raw_answer = response[0]['generated_text'].strip()
    
    # ۴. استخراج از تگ ANSWER
    match = re.search(r'<ANSWER>\s*([A-D](?:\s*,\s*[A-D])*)\s*</ANSWER>', raw_answer)
    if match:
        clean_answer = match.group(1).replace(' ', '')
    else:
        fallback_match = re.search(r'[A-D](?:\s*,\s*[A-D])*', raw_answer)
        clean_answer = fallback_match.group(0).replace(' ', '') if fallback_match else "نامشخص"
    
    # ۵. محاسبه امتیاز
    golden = sample.get('golden_answer', '')
    score = calculate_score(clean_answer, golden)
    total_score += score
    
    results_log.append({
        "id": sample['id'],
        "target_event": sample['target_event'],
        "predicted": clean_answer,
        "golden": golden,
        "score": score,
        "raw_reasoning": raw_answer # ذخیره استدلال برای تحلیل دقیق‌تر
    })

# ==========================================
# نمایش نتایج نهایی
# ==========================================
average_score = total_score / len(dataset)
print("\n" + "="*50)
print("🏆 نتایج نهایی ارزیابی (Fine-Tuned Model + Semantic RAG + CoT) 🏆")
print("="*50)
print(f"تعداد کل نمونه‌ها: {len(dataset)}")
print(f"مجموع امتیازات کسب شده: {total_score}")
print(f"میانگین امتیاز (Accuracy): {average_score:.4f} یا {average_score * 100:.2f}%")
print("="*50)

print("\n🔍 تحلیل خطاها (نمونه‌های با امتیاز ۰):")
error_count = 0
for res in results_log:
    if res['score'] == 0.0:
        print(f"ID: {res['id']} | Predicted: {res['predicted']} | Golden: {res['golden']}")
        print(f"Reasoning: {res['raw_reasoning'][:100]}...\n")
        error_count += 1
        if error_count >= 5:
            break
# Out:
# شروع ارزیابی روی 400 نمونه...
# Processing Samples:   0%|          | 0/400 [00:00<?, ?it/s]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   0%|          | 1/400 [00:10<1:07:15, 10.11s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   0%|          | 2/400 [00:21<1:12:04, 10.87s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   1%|          | 3/400 [00:33<1:16:34, 11.57s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   1%|          | 4/400 [00:46<1:18:34, 11.91s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   1%|▏         | 5/400 [01:00<1:22:53, 12.59s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   2%|▏         | 6/400 [01:11<1:19:03, 12.04s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   2%|▏         | 7/400 [01:25<1:23:55, 12.81s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   2%|▏         | 8/400 [01:36<1:20:48, 12.37s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   2%|▏         | 9/400 [01:51<1:25:32, 13.13s/it]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   2%|▎         | 10/400 [02:03<1:22:49, 12.74s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   3%|▎         | 11/400 [02:12<1:14:30, 11.49s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   3%|▎         | 12/400 [02:25<1:18:25, 12.13s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   3%|▎         | 13/400 [02:38<1:18:36, 12.19s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   4%|▎         | 14/400 [02:52<1:21:44, 12.71s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   4%|▍         | 15/400 [03:03<1:18:52, 12.29s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   4%|▍         | 16/400 [03:13<1:13:38, 11.51s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   4%|▍         | 17/400 [03:24<1:13:59, 11.59s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   4%|▍         | 18/400 [03:38<1:17:21, 12.15s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   5%|▍         | 19/400 [03:50<1:17:55, 12.27s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   5%|▌         | 20/400 [04:06<1:23:10, 13.13s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   5%|▌         | 21/400 [04:19<1:22:41, 13.09s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   6%|▌         | 22/400 [04:28<1:15:16, 11.95s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   6%|▌         | 23/400 [04:40<1:14:40, 11.89s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   6%|▌         | 24/400 [04:52<1:15:01, 11.97s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   6%|▋         | 25/400 [05:04<1:15:12, 12.03s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   6%|▋         | 26/400 [05:15<1:13:10, 11.74s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   7%|▋         | 27/400 [05:27<1:13:40, 11.85s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   7%|▋         | 28/400 [05:39<1:13:27, 11.85s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   7%|▋         | 29/400 [05:50<1:11:21, 11.54s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   8%|▊         | 30/400 [06:01<1:10:54, 11.50s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   8%|▊         | 31/400 [06:10<1:06:33, 10.82s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   8%|▊         | 32/400 [06:23<1:10:20, 11.47s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   8%|▊         | 33/400 [06:34<1:09:18, 11.33s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   8%|▊         | 34/400 [06:45<1:08:10, 11.18s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   9%|▉         | 35/400 [06:56<1:06:48, 10.98s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   9%|▉         | 36/400 [07:06<1:05:14, 10.75s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:   9%|▉         | 37/400 [07:15<1:01:58, 10.24s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  10%|▉         | 38/400 [07:26<1:02:26, 10.35s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  10%|▉         | 39/400 [07:36<1:02:35, 10.40s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  10%|█         | 40/400 [07:48<1:05:05, 10.85s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  10%|█         | 41/400 [07:58<1:03:39, 10.64s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  10%|█         | 42/400 [08:07<1:00:14, 10.10s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  11%|█         | 43/400 [08:16<58:33,  9.84s/it]  Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  11%|█         | 44/400 [08:24<54:59,  9.27s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  11%|█▏        | 45/400 [08:36<59:06,  9.99s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  12%|█▏        | 46/400 [08:47<1:01:15, 10.38s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  12%|█▏        | 47/400 [09:01<1:07:25, 11.46s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  12%|█▏        | 48/400 [09:11<1:05:05, 11.10s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  12%|█▏        | 49/400 [09:20<1:01:21, 10.49s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  12%|█▎        | 50/400 [09:32<1:02:20, 10.69s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  13%|█▎        | 51/400 [09:42<1:01:23, 10.55s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  13%|█▎        | 52/400 [09:53<1:02:05, 10.71s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  13%|█▎        | 53/400 [10:04<1:03:17, 10.94s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  14%|█▎        | 54/400 [10:17<1:05:55, 11.43s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  14%|█▍        | 55/400 [10:28<1:05:36, 11.41s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  14%|█▍        | 56/400 [10:43<1:10:29, 12.29s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  14%|█▍        | 57/400 [10:56<1:11:44, 12.55s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  14%|█▍        | 58/400 [11:10<1:14:24, 13.06s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  15%|█▍        | 59/400 [11:22<1:12:29, 12.75s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  15%|█▌        | 60/400 [11:34<1:10:07, 12.37s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  15%|█▌        | 61/400 [11:46<1:09:59, 12.39s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  16%|█▌        | 62/400 [11:57<1:07:37, 12.00s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  16%|█▌        | 63/400 [12:06<1:02:03, 11.05s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  16%|█▌        | 64/400 [12:18<1:03:36, 11.36s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  16%|█▋        | 65/400 [12:28<1:01:42, 11.05s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  16%|█▋        | 66/400 [12:40<1:02:24, 11.21s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  17%|█▋        | 67/400 [12:49<58:53, 10.61s/it]  Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  17%|█▋        | 68/400 [13:01<1:01:12, 11.06s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  17%|█▋        | 69/400 [13:11<59:04, 10.71s/it]  Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  18%|█▊        | 70/400 [13:24<1:02:44, 11.41s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  18%|█▊        | 71/400 [13:37<1:04:15, 11.72s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  18%|█▊        | 72/400 [13:48<1:03:21, 11.59s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  18%|█▊        | 73/400 [14:03<1:09:06, 12.68s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  18%|█▊        | 74/400 [14:14<1:06:05, 12.16s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  19%|█▉        | 75/400 [14:27<1:06:25, 12.26s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  19%|█▉        | 76/400 [14:36<1:01:03, 11.31s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  19%|█▉        | 77/400 [14:47<1:01:31, 11.43s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  20%|█▉        | 78/400 [14:58<1:00:42, 11.31s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  20%|█▉        | 79/400 [15:11<1:02:49, 11.74s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  20%|██        | 80/400 [15:26<1:07:20, 12.63s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  20%|██        | 81/400 [15:38<1:06:07, 12.44s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  20%|██        | 82/400 [15:56<1:14:26, 14.05s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  21%|██        | 83/400 [16:05<1:06:58, 12.68s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  21%|██        | 84/400 [16:15<1:02:31, 11.87s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  21%|██▏       | 85/400 [16:31<1:08:20, 13.02s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  22%|██▏       | 86/400 [16:41<1:03:55, 12.22s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  22%|██▏       | 87/400 [16:51<59:46, 11.46s/it]  Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  22%|██▏       | 88/400 [17:03<1:00:51, 11.70s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  22%|██▏       | 89/400 [17:12<56:40, 10.93s/it]  Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  22%|██▎       | 90/400 [17:24<57:35, 11.15s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  23%|██▎       | 91/400 [17:35<57:56, 11.25s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  23%|██▎       | 92/400 [17:48<59:07, 11.52s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  23%|██▎       | 93/400 [17:57<55:15, 10.80s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  24%|██▎       | 94/400 [18:08<55:19, 10.85s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  24%|██▍       | 95/400 [18:18<54:19, 10.69s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  24%|██▍       | 96/400 [18:27<51:36, 10.19s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  24%|██▍       | 97/400 [18:35<48:01,  9.51s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  24%|██▍       | 98/400 [18:43<45:04,  8.96s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  25%|██▍       | 99/400 [18:55<49:45,  9.92s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  25%|██▌       | 100/400 [19:05<50:26, 10.09s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  25%|██▌       | 101/400 [19:19<55:07, 11.06s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  26%|██▌       | 102/400 [19:27<51:11, 10.31s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  26%|██▌       | 103/400 [19:38<52:33, 10.62s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  26%|██▌       | 104/400 [19:53<59:00, 11.96s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  26%|██▋       | 105/400 [20:03<55:02, 11.19s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  26%|██▋       | 106/400 [20:15<56:26, 11.52s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  27%|██▋       | 107/400 [20:26<55:16, 11.32s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  27%|██▋       | 108/400 [20:38<56:34, 11.62s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  27%|██▋       | 109/400 [20:49<55:26, 11.43s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  28%|██▊       | 110/400 [21:03<58:46, 12.16s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  28%|██▊       | 111/400 [21:13<55:45, 11.58s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  28%|██▊       | 112/400 [21:24<54:32, 11.36s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  28%|██▊       | 113/400 [21:38<57:47, 12.08s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  28%|██▊       | 114/400 [21:48<55:05, 11.56s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  29%|██▉       | 115/400 [22:00<54:36, 11.50s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  29%|██▉       | 116/400 [22:10<52:12, 11.03s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  29%|██▉       | 117/400 [22:22<54:01, 11.46s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  30%|██▉       | 118/400 [22:32<52:17, 11.13s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  30%|██▉       | 119/400 [22:45<54:41, 11.68s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  30%|███       | 120/400 [22:57<54:18, 11.64s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  30%|███       | 121/400 [23:08<53:00, 11.40s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  30%|███       | 122/400 [23:19<52:59, 11.44s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  31%|███       | 123/400 [23:31<52:47, 11.44s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  31%|███       | 124/400 [23:41<50:25, 10.96s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  31%|███▏      | 125/400 [23:52<50:39, 11.05s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  32%|███▏      | 126/400 [24:04<51:38, 11.31s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  32%|███▏      | 127/400 [24:15<50:54, 11.19s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  32%|███▏      | 128/400 [24:26<50:41, 11.18s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  32%|███▏      | 129/400 [24:38<51:19, 11.36s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  32%|███▎      | 130/400 [24:49<51:08, 11.37s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  33%|███▎      | 131/400 [25:00<50:08, 11.18s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  33%|███▎      | 132/400 [25:11<50:25, 11.29s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  33%|███▎      | 133/400 [25:24<52:29, 11.79s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  34%|███▎      | 134/400 [25:35<51:06, 11.53s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  34%|███▍      | 135/400 [25:45<47:57, 10.86s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  34%|███▍      | 136/400 [25:59<52:17, 11.88s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  34%|███▍      | 137/400 [26:12<53:11, 12.13s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  34%|███▍      | 138/400 [26:21<49:22, 11.31s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  35%|███▍      | 139/400 [26:35<53:13, 12.24s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  35%|███▌      | 140/400 [26:47<52:45, 12.18s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  35%|███▌      | 141/400 [27:00<52:51, 12.25s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  36%|███▌      | 142/400 [27:10<49:44, 11.57s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  36%|███▌      | 143/400 [27:22<50:09, 11.71s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  36%|███▌      | 144/400 [27:36<53:10, 12.46s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  36%|███▋      | 145/400 [27:47<51:20, 12.08s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  36%|███▋      | 146/400 [27:57<48:32, 11.47s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  37%|███▋      | 147/400 [28:09<48:08, 11.42s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  37%|███▋      | 148/400 [28:23<51:10, 12.18s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# ...
#
# Processing Samples:  88%|████████▊ | 354/400 [1:07:36<08:19, 10.85s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  89%|████████▉ | 355/400 [1:07:46<07:51, 10.47s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  89%|████████▉ | 356/400 [1:08:00<08:26, 11.50s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  89%|████████▉ | 357/400 [1:08:11<08:14, 11.50s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  90%|████████▉ | 358/400 [1:08:20<07:29, 10.69s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  90%|████████▉ | 359/400 [1:08:32<07:34, 11.08s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  90%|█████████ | 360/400 [1:08:43<07:22, 11.06s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  90%|█████████ | 361/400 [1:08:55<07:20, 11.29s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  90%|█████████ | 362/400 [1:09:08<07:36, 12.02s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  91%|█████████ | 363/400 [1:09:20<07:23, 11.98s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  91%|█████████ | 364/400 [1:09:33<07:13, 12.04s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  91%|█████████▏| 365/400 [1:09:46<07:16, 12.46s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  92%|█████████▏| 366/400 [1:10:00<07:17, 12.88s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  92%|█████████▏| 367/400 [1:10:09<06:30, 11.84s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  92%|█████████▏| 368/400 [1:10:20<06:08, 11.51s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  92%|█████████▏| 369/400 [1:10:31<05:47, 11.21s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  92%|█████████▎| 370/400 [1:10:42<05:38, 11.29s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  93%|█████████▎| 371/400 [1:10:53<05:21, 11.09s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  93%|█████████▎| 372/400 [1:11:03<05:07, 11.00s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  93%|█████████▎| 373/400 [1:11:16<05:06, 11.35s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  94%|█████████▎| 374/400 [1:11:29<05:08, 11.88s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  94%|█████████▍| 375/400 [1:11:39<04:45, 11.41s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  94%|█████████▍| 376/400 [1:11:49<04:27, 11.13s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  94%|█████████▍| 377/400 [1:12:00<04:11, 10.94s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  94%|█████████▍| 378/400 [1:12:11<04:02, 11.02s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  95%|█████████▍| 379/400 [1:12:22<03:51, 11.00s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  95%|█████████▌| 380/400 [1:12:32<03:30, 10.53s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  95%|█████████▌| 381/400 [1:12:45<03:35, 11.34s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  96%|█████████▌| 382/400 [1:12:57<03:30, 11.72s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  96%|█████████▌| 383/400 [1:13:11<03:27, 12.20s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  96%|█████████▌| 384/400 [1:13:23<03:13, 12.09s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  96%|█████████▋| 385/400 [1:13:35<03:02, 12.18s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  96%|█████████▋| 386/400 [1:13:46<02:46, 11.86s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  97%|█████████▋| 387/400 [1:13:56<02:26, 11.28s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  97%|█████████▋| 388/400 [1:14:08<02:17, 11.48s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  97%|█████████▋| 389/400 [1:14:18<02:02, 11.17s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  98%|█████████▊| 390/400 [1:14:32<01:59, 11.99s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  98%|█████████▊| 391/400 [1:14:48<01:57, 13.09s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  98%|█████████▊| 392/400 [1:15:01<01:44, 13.10s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  98%|█████████▊| 393/400 [1:15:10<01:21, 11.70s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  98%|█████████▊| 394/400 [1:15:19<01:06, 11.11s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  99%|█████████▉| 395/400 [1:15:30<00:55, 11.15s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  99%|█████████▉| 396/400 [1:15:40<00:42, 10.65s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples:  99%|█████████▉| 397/400 [1:15:51<00:32, 10.83s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples: 100%|█████████▉| 398/400 [1:16:01<00:20, 10.39s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples: 100%|█████████▉| 399/400 [1:16:11<00:10, 10.36s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Processing Samples: 100%|██████████| 400/400 [1:16:23<00:00, 11.46s/it]
# ==================================================
# 🏆 نتایج نهایی ارزیابی (Fine-Tuned Model + Semantic RAG + CoT) 🏆
# ==================================================
# تعداد کل نمونه‌ها: 400
# مجموع امتیازات کسب شده: 328.5
# میانگین امتیاز (Accuracy): 0.8213 یا 82.12%
# ==================================================
#
# 🔍 تحلیل خطاها (نمونه‌های با امتیاز ۰):
# ID: q-2057 | Predicted: A,B | Golden: B
# Reasoning: The event "Twitter removed Trump's tweets and locked his account" is the direct cause of the Target ...
#
# ID: q-2059 | Predicted: A | Golden: D
# Reasoning: The event "Trump addressed the crowd" is the direct cause of the Target Event "Trump was impeached f...
#
# ID: q-2072 | Predicted: B,D | Golden: D
# Reasoning: Mark Zuckerberg's announcement of Facebook's bet on the metaverse in July directly led to the compan...
#
# ID: q-2076 | Predicted: C,D | Golden: D
# Reasoning: The event "On August 15, 2021, the Taliban seized the presidential palace in Kabul and declared the ...
#
# ID: q-2092 | Predicted: A,B,C | Golden: A,B
# Reasoning: The event "DeepSeek's model outperformed Meta's Llama 3.1, OpenAI's GPT-4o, and Anthropic's Claude S...

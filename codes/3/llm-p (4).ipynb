# %%
# !git clone https://github.com/sooo66/semeval2026-task12-dataset.git
# Out:
# Cloning into 'semeval2026-task12-dataset'...
# remote: Enumerating objects: 69, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 69 (delta 30), reused 51 (delta 15), pack-reused 0 (from 0)
# Receiving objects: 100% (69/69), 6.72 MiB | 23.08 MiB/s, done.
# Resolving deltas: 100% (30/30), done.

# %%
import json
import re

def clean_text(text):
    """
    پاک‌سازی اولیه متون
    """
    if not text or not isinstance(text, str):
        return ""
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

def load_and_merge_data(questions_path, docs_path):
    # ۱. خواندن فایل اسناد (docs.json)
    with open(docs_path, 'r', encoding='utf-8') as f:
        docs_raw = json.load(f)
        
    # ۲. تبدیل هوشمند لیست به دیکشنری برای جستجوی سریع بر اساس topic_id
    docs_dict = {}
    
    # بررسی می‌کنیم که آیا فایل اصلی لیستی از آیتم‌هاست
    if isinstance(docs_raw, list):
        for item in docs_raw:
            if not isinstance(item, dict):
                continue
                
            t_id = item.get("topic_id")
            if not t_id:
                continue
                
            if t_id not in docs_dict:
                docs_dict[t_id] = []
                
            # حالت اول: اگر آیتم شامل لیستی از اسناد در کلید docs باشد
            if "docs" in item or "documents" in item:
                inner_docs = item.get("docs", item.get("documents", []))
                for d in inner_docs:
                    if isinstance(d, dict):
                        # استخراج متن از دیکشنری داخلی
                        text_val = d.get("text", d.get("content", d.get("doc", "")))
                        docs_dict[t_id].append(text_val)
                    elif isinstance(d, str):
                        docs_dict[t_id].append(d)
            # حالت دوم: اگر خود آیتم مستقیماً یک سند باشد
            else:
                text_val = item.get("text", item.get("content", item.get("doc", "")))
                if text_val:
                    docs_dict[t_id].append(text_val)

    merged_dataset = []
    
    # ۳. خواندن فایل سوالات و اتصال به اسناد
    with open(questions_path, 'r', encoding='utf-8') as f:
        for line in f:
            if not line.strip():
                continue
                
            question_item = json.loads(line.strip())
            topic_id = question_item.get("topic_id")
            
            # استخراج اسناد از دیکشنری که بالاتر ساختیم (این بار بدون خطا)
            related_docs = docs_dict.get(topic_id, [])
            
            # پاک‌سازی و ترکیب متون
            cleaned_docs = [clean_text(doc) for doc in related_docs if doc]
            context_text = " ".join(cleaned_docs)
            
            # ۴. ساختار نهایی
            merged_item = {
                "id": question_item.get("id"),
                "topic_id": topic_id,
                "target_event": clean_text(question_item.get("target_event")),
                "options": {
                    "A": clean_text(question_item.get("option_A")),
                    "B": clean_text(question_item.get("option_B")),
                    "C": clean_text(question_item.get("option_C")),
                    "D": clean_text(question_item.get("option_D"))
                },
                "golden_answer": question_item.get("golden_answer"),
                "context": context_text 
            }
            merged_dataset.append(merged_item)
            
    return merged_dataset

# ==========================================
# اجرای کد
# ==========================================

QUESTIONS_FILE = 'semeval2026-task12-dataset/sample_data/questions.jsonl'
DOCS_FILE = 'semeval2026-task12-dataset/sample_data/docs.json'

dataset = load_and_merge_data(QUESTIONS_FILE, DOCS_FILE)

if dataset:
    print("✅ پردازش با موفقیت انجام شد!\n")
    print(f"🔹 رویداد هدف: {dataset[0]['target_event']}")
    print(f"🔹 گزینه‌ها:")
    for key, val in dataset[0]['options'].items():
        print(f"   {key}: {val}")
    print(f"🔹 پاسخ درست: {dataset[0]['golden_answer']}")
    print(f"🔹 طول متن زمینه (Context): {len(dataset[0]['context'])} کاراکتر")
else:
    print("مجموعه داده خالی است!")
# Out:
# ✅ پردازش با موفقیت انجام شد!
#
# 🔹 رویداد هدف: Videos of the assassination circulated on social media.
# 🔹 گزینه‌ها:
#    A: The shooter used a handmade gun.
#    B: Security arrested the suspected gunman, Tetsuya Yamagami.
#    C: Shinzo Abe became the deputy chief cabinet secretary in the early 2000s.
#    D: A man fired twice at Shinzo Abe.
# 🔹 پاسخ درست: D
# 🔹 طول متن زمینه (Context): 94617 کاراکتر

# %%
# # در صورت نیاز کتابخانه‌های زیر را نصب کنید:
# # !pip install transformers torch

# import json

# def generate_prompt(sample, max_context_chars=4000):
#     """
#     این تابع پرامپت نهایی را برای ارسال به مدل زبانی می‌سازد.
#     برای جلوگیری از خطای محدودیت توکن در مدل پایه، طول کانتکست محدود شده است.
#     """
    
#     # برش متن زمینه (کانتکست) برای مدل پایه
#     context = sample['context']
#     if len(context) > max_context_chars:
#         context = context[:max_context_chars] + "\n... [متن به دلیل طولانی بودن برش داده شد] ..."

#     # طراحی ساختار پرامپت با دستورالعمل‌های سخت‌گیرانه (Strict Instructions)
#     prompt = f"""You are an expert AI system specialized in Abductive Event Reasoning. 
# Your task is to find the most likely direct cause of a given event based on the provided news context.

# Read the context carefully. Then, look at the Target Event and choose the most logical direct cause from the Options.

# Context:
# {context}

# Target Event: {sample['target_event']}

# Options:
# A) {sample['options']['A']}
# B) {sample['options']['B']}
# C) {sample['options']['C']}
# D) {sample['options']['D']}

# Which option is the most likely direct cause of the Target Event? 
# Output ONLY the letter corresponding to the correct option (A, B, C, or D). Do not write anything else.
# Answer: """
    
#     return prompt

# # ==========================================
# # تست ساخت پرامپت روی نمونه اول (dataset[0])
# # ==========================================

# sample_prompt = generate_prompt(dataset[0])
# print("✅ پرامپت طراحی شده برای ارسال به مدل:\n")
# print("-" * 50)
# print(sample_prompt)
# print("-" * 50)

# # ==========================================
# # شبیه‌سازی فراخوانی مدل (LLM Inference)
# # ==========================================
# # توجه: اگر در گوگل کولب هستید و منابع GPU دارید، می‌توانید کدهای زیر را از حالت کامنت خارج کنید 
# # تا یک مدل سبک را به صورت واقعی اجرا کنید.


# from transformers import pipeline

# print("\nدر حال بارگذاری مدل زبانی (این مرحله ممکن است کمی زمان‌بر باشد)...")
# # استفاده از یک مدل کوچک و سریع برای تست اولیه
# # برای نتایج بهتر در آینده می‌توانید از مدل‌های بزرگتر استفاده کنید
# pipe = pipeline("text-generation", model="Qwen/Qwen2.5-0.5B-Instruct", device_map="auto")

# print("مدل بارگذاری شد. در حال تولید پاسخ...")
# response = pipe(
#     sample_prompt, 
#     max_new_tokens=5, # ما فقط یک حرف می‌خواهیم، پس توکن‌های تولیدی را محدود می‌کنیم
#     temperature=0.1,  # دمای پایین برای پاسخ‌های قطعی‌تر و منطقی‌تر
#     do_sample=True
# )

# generated_text = response[0]['generated_text']
# # استخراج خروجی مدل (حذف پرامپت ورودی از خروجی نهایی)
# answer_only = generated_text.replace(sample_prompt, "").strip()

# print(f"\n🧠 خروجی مدل: {answer_only}")
# print(f"🎯 پاسخ درست (Golden Answer): {dataset[0]['golden_answer']}")

# %%
# # در صورت نیاز کتابخانه را نصب کنید:
# # !pip install scikit-learn

# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity
# import re

# def retrieve_relevant_context(sample, top_k=7):
#     """
#     این تابع با استفاده از TF-IDF مهم‌ترین جملات کانتکست را استخراج می‌کند.
#     top_k: تعداد جملاتی که می‌خواهیم استخراج کنیم.
#     """
#     context = sample['context']
    
#     # ۱. شکستن متن طولانی به جملات مجزا بر اساس نقطه، علامت سوال و تعجب
#     sentences = re.split(r'(?<=[.!?])\s+', context)
#     # فیلتر کردن جملات خیلی کوتاه یا خالی
#     sentences = [s.strip() for s in sentences if len(s.strip()) > 20]
    
#     if not sentences:
#         return ""

#     # ۲. ساخت کوئری: رویداد هدف + تمام گزینه‌ها
#     # دلیل: ما جملاتی را می‌خواهیم که هم درباره رویداد صحبت کنند و هم به علت‌های احتمالی اشاره داشته باشند
#     query = sample['target_event'] + " " + " ".join(sample['options'].values())

#     # ۳. برداری کردن متون با TF-IDF (و حذف کلمات توقف انگلیسی مانند the, is, at)
#     vectorizer = TfidfVectorizer(stop_words='english')
    
#     try:
#         # ساخت ماتریس جملات و بردار کوئری
#         tfidf_matrix = vectorizer.fit_transform(sentences)
#         query_vector = vectorizer.transform([query])
#     except ValueError:
#         # در صورتی که متن به شدت کوتاه باشد یا فقط شامل Stop-words باشد
#         return " ".join(sentences[:top_k])

#     # ۴. محاسبه شباهت کسینوسی بین کوئری و تک‌تک جملات
#     similarities = cosine_similarity(query_vector, tfidf_matrix).flatten()

#     # ۵. پیدا کردن ایندکس k جمله که بیشترین امتیاز شباهت را دارند
#     # argsort آرایه را صعودی مرتب می‌کند، پس k تای آخر را جدا می‌کنیم
#     top_indices = similarities.argsort()[-top_k:]

#     # ۶. نکته کلیدی: مرتب‌سازی مجدد ایندکس‌ها بر اساس ترتیب اصلی متن!
#     # این کار باعث می‌شود جملات استخراج شده، انسجام و سیر زمانی خود را حفظ کنند و مدل گیج نشود.
#     top_indices_sorted = sorted(top_indices)
    
#     # ترکیب جملات برتر
#     best_sentences = [sentences[i] for i in top_indices_sorted]
#     filtered_context = " ".join(best_sentences)

#     return filtered_context

# # ==========================================
# # تست سیستم بازیابی روی نمونه شینزو آبه (dataset[0])
# # ==========================================

# # فراخوانی تابع فیلتر هوشمند
# smart_context = retrieve_relevant_context(dataset[0], top_k=5)

# print("✅ کانتکست فیلتر شده (Smart Context):\n")
# print("-" * 50)
# print(smart_context)
# print("-" * 50)
# print(f"\nطول کانتکست جدید: {len(smart_context)} کاراکتر (کاهش چشمگیر از 94,617!)")

# %%
# در صورت نیاز کتابخانه‌های زیر را نصب کنید:
# !pip install transformers torch scikit-learn sentence-transformers

import json
import re
import torch
from transformers import pipeline
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# ==========================================
# ۰. بارگذاری مناسب‌ترین مدل Embedding برای این تسک
# ==========================================
print("در حال بارگذاری مدل Embedding قدرتمند (BGE-Large)...")
# این مدل یکی از بهترین مدل‌های متن‌باز برای بازیابی اطلاعات معنایی است
embedder = SentenceTransformer('BAAI/bge-large-en-v1.5') 

# ==========================================
# ۱. تابع بازیابی اطلاعات (Semantic RAG)
# ==========================================
def retrieve_relevant_context(sample, top_k=6):
    context = sample['context']
    
    # شکستن متن طولانی به جملات مجزا
    sentences = re.split(r'(?<=[.!?])\s+', context)
    sentences = [s.strip() for s in sentences if len(s.strip()) > 20]
    
    if not sentences: return ""

    # ساخت کوئری: رویداد هدف + تمام گزینه‌ها
    query = sample['target_event'] + " " + " ".join(sample['options'].values())
    
    # تبدیل متون به بردار
    sentence_embeddings = embedder.encode(sentences)
    query_embedding = embedder.encode([query])

    # محاسبه شباهت و استخراج ۶ جمله برتر با حفظ ترتیب زمانی
    similarities = cosine_similarity(query_embedding, sentence_embeddings).flatten()
    top_indices = similarities.argsort()[-top_k:]
    top_indices_sorted = sorted(top_indices) 
    
    return " ".join([sentences[i] for i in top_indices_sorted])

# ==========================================
# ۲. تابع ساخت پیام‌ها با Few-Shot CoT (بدون تغییر)
# ==========================================
def generate_messages(sample, filtered_context):
    few_shot_examples = """
Example 1:
Context: The building's structural integrity was compromised after the explosion. Investigators found traces of C4.
Target Event: The roof collapsed.
Options: A) Heavy rain started. B) An explosive device detonated. C) The building was old. D) Firefighters arrived.
Reasoning: The context mentions an explosion and C4, which is an explosive. Detonation of such a device is the direct cause of the collapse.
<ANSWER>B</ANSWER>

Example 2:
Context: Multiple witness reports and CCTV footage showed two different individuals firing from the balcony and the street level.
Target Event: Chaos erupted in the plaza.
Options: A) A person fired from the balcony. B) A car honked. C) A person fired from the street. D) Police arrived later.
Reasoning: Both shooters (balcony and street) caused the chaos directly according to the footage.
<ANSWER>A,C</ANSWER>
"""

    messages = [
        {
            "role": "system", 
            "content": f"You are an expert AI specialized in Abductive Event Reasoning. Use the following examples as a guide:\n{few_shot_examples}\n\nTask: First, briefly reason based on the provided Context. Then, output the uppercase letter(s) of the correct option(s) inside <ANSWER> tags."
        },
        {
            "role": "user", 
            "content": f"Context: {filtered_context}\n\nTarget Event: {sample['target_event']}\n\nOptions:\nA) {sample['options']['A']}\nB) {sample['options']['B']}\nC) {sample['options']['C']}\nD) {sample['options']['D']}\n\nReason and output final answer in <ANSWER> tags."
        }
    ]
    return messages

# ==========================================
# ۳. بارگذاری مدل زبانی اصلی و تست روی یک نمونه
# ==========================================
print("\nدر حال بارگذاری مدل زبانی Qwen2.5-7B...")
pipe = pipeline(
    "text-generation", 
    model="Qwen/Qwen2.5-7B-Instruct", 
    device_map="auto",
    torch_dtype=torch.float16 
)
print("✅ مدل‌ها با موفقیت بارگذاری شدند.\n")

# تست سیستم روی نمونه اول
sample_data = dataset[0]
smart_context = retrieve_relevant_context(sample_data, top_k=6)
messages = generate_messages(sample_data, smart_context)
formatted_prompt = pipe.tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)

response = pipe(
    formatted_prompt, 
    max_new_tokens=200, 
    temperature=0.1, # دمای پایین برای پاسخ‌های منطقی و پایدار
    do_sample=True,
    pad_token_id=pipe.tokenizer.eos_token_id
)

generated_text = response[0]['generated_text']
raw_answer = generated_text.replace(formatted_prompt, "").strip()

match = re.search(r'<ANSWER>\s*([A-D](?:\s*,\s*[A-D])*)\s*</ANSWER>', raw_answer)
if match:
    clean_answer = match.group(1).replace(' ', '')
else:
    fallback = re.search(r'[A-D](?:\s*,\s*[A-D])*', raw_answer)
    clean_answer = fallback.group(0).replace(' ', '') if fallback else "نامشخص"

print(f"🧠 استدلال کامل مدل:\n{raw_answer}")
print(f"✨ خروجی تمیز شده و نهایی: {clean_answer}")
print(f"🎯 پاسخ درست (Golden Answer): {sample_data['golden_answer']}")
# Out:
# در حال بارگذاری مدل Embedding قدرتمند (BGE-Large)...
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/779 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: BAAI/bge-large-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]
# در حال بارگذاری مدل زبانی Qwen2.5-7B...
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# ✅ مدل‌ها با موفقیت بارگذاری شدند.
# Passing `generation_config` together with generation-related arguments=({'do_sample', 'pad_token_id', 'max_new_tokens', 'temperature'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 🧠 استدلال کامل مدل:
# Reasoning: The context mentions that multiple videos of the attack circulated on social media, where a gunman fired a homemade, double-barreled weapon twice at Abe. This directly supports the target event of videos circulating on social media.
#
# <ANSWER>D</ANSWER>
# ✨ خروجی تمیز شده و نهایی: D
# 🎯 پاسخ درست (Golden Answer): D

# %%
import json
import re
from tqdm import tqdm

# ==========================================
# تابع ارزیابی (بدون تغییر)
# ==========================================
def calculate_score(predicted_answers_str, golden_answers_str):
    if predicted_answers_str == "نامشخص": return 0.0
    P = set([ans.strip() for ans in predicted_answers_str.split(',') if ans.strip()])
    G = set([ans.strip() for ans in golden_answers_str.split(',') if ans.strip()])
    if P == G and len(P) > 0: return 1.0  
    elif P.issubset(G) and len(P) > 0: return 0.5  
    else: return 0.0  

# ==========================================
# ارزیابی کلی روی کل دیتاست
# ==========================================
print(f"\nشروع ارزیابی روی {len(dataset)} نمونه...")
total_score = 0
results_log = []

for index, sample in enumerate(tqdm(dataset, desc="Evaluating")):
    
    # ۱. استخراج کانتکست
    smart_context = retrieve_relevant_context(sample, top_k=6)
    
    # ۲. ساخت پرامپت
    messages = generate_messages(sample, smart_context)
    formatted_prompt = pipe.tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    
    # ۳. تولید خروجی یک‌باره (حذف Self-Consistency)
    response = pipe(
        formatted_prompt, 
        max_new_tokens=200, 
        temperature=0.1, # بازگشت به دمای پایین
        do_sample=True,
        pad_token_id=pipe.tokenizer.eos_token_id
    )
    
    output = response[0]['generated_text'].replace(formatted_prompt, "").strip()
    
    # ۴. استخراج از تگ ANSWER
    match = re.search(r'<ANSWER>\s*([A-D](?:\s*,\s*[A-D])*)\s*</ANSWER>', output)
    if match:
        clean_answer = match.group(1).replace(' ', '')
    else:
        fallback = re.search(r'[A-D](?:\s*,\s*[A-D])*', output)
        clean_answer = fallback.group(0).replace(' ', '') if fallback else "نامشخص"
    
    # ۵. محاسبه امتیاز
    score = calculate_score(clean_answer, sample['golden_answer'])
    total_score += score
    
    results_log.append({
        "id": sample['id'], 
        "predicted": clean_answer, 
        "golden": sample['golden_answer'], 
        "score": score
    })

# ==========================================
# نمایش نتایج نهایی
# ==========================================
average_score = total_score / len(dataset)
print("\n" + "="*50)
print("🏆 نتایج نهایی ارزیابی (Semantic RAG + Few-Shot CoT) 🏆")
print("="*50)
print(f"تعداد کل نمونه‌ها: {len(dataset)}")
print(f"مجموع امتیازات کسب شده: {total_score}")
print(f"میانگین امتیاز (Accuracy): {average_score:.4f} یا {average_score * 100:.2f}%")
print("="*50)

print("\n🔍 تحلیل خطاها (نمونه‌های با امتیاز ۰):")
error_count = 0
for res in results_log:
    if res['score'] == 0.0:
        print(f"ID: {res['id']} | Predicted: {res['predicted']} | Golden: {res['golden']}")
        error_count += 1
        if error_count >= 5:
            break
# Out:
# شروع ارزیابی روی 200 نمونه...
# Evaluating:   0%|          | 0/200 [00:00<?, ?it/s]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:   0%|          | 1/200 [00:09<30:29,  9.19s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:   1%|          | 2/200 [00:22<37:22, 11.32s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:   2%|▏         | 3/200 [00:31<34:32, 10.52s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:   2%|▏         | 4/200 [00:42<34:32, 10.57s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:   2%|▎         | 5/200 [00:55<37:27, 11.53s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:   3%|▎         | 6/200 [01:09<39:41, 12.28s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:   4%|▎         | 7/200 [01:17<35:07, 10.92s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:   4%|▍         | 8/200 [01:29<35:51, 11.21s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:   4%|▍         | 9/200 [01:41<36:39, 11.52s/it]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:   5%|▌         | 10/200 [02:00<44:20, 14.00s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:   6%|▌         | 11/200 [02:12<41:59, 13.33s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:   6%|▌         | 12/200 [02:20<36:41, 11.71s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:   6%|▋         | 13/200 [02:44<47:43, 15.31s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:   7%|▋         | 14/200 [02:58<46:51, 15.12s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:   8%|▊         | 15/200 [03:10<43:31, 14.11s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:   8%|▊         | 16/200 [03:20<38:50, 12.67s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:   8%|▊         | 17/200 [03:36<41:53, 13.73s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:   9%|▉         | 18/200 [03:50<42:17, 13.94s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  10%|▉         | 19/200 [04:11<48:09, 15.96s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  10%|█         | 20/200 [04:23<44:15, 14.75s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  10%|█         | 21/200 [04:36<42:25, 14.22s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  11%|█         | 22/200 [04:57<48:34, 16.38s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  12%|█▏        | 23/200 [05:14<48:14, 16.36s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  12%|█▏        | 24/200 [05:24<43:12, 14.73s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  12%|█▎        | 25/200 [05:41<44:13, 15.16s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  13%|█▎        | 26/200 [05:54<42:23, 14.62s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  14%|█▎        | 27/200 [06:05<39:12, 13.60s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  14%|█▍        | 28/200 [06:17<37:26, 13.06s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  14%|█▍        | 29/200 [06:28<35:09, 12.34s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  15%|█▌        | 30/200 [06:42<36:32, 12.90s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  16%|█▌        | 31/200 [06:55<36:07, 12.83s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  16%|█▌        | 32/200 [07:07<35:21, 12.63s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  16%|█▋        | 33/200 [07:20<36:04, 12.96s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  17%|█▋        | 34/200 [07:35<36:51, 13.32s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  18%|█▊        | 35/200 [07:49<37:38, 13.69s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  18%|█▊        | 36/200 [07:57<33:00, 12.08s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  18%|█▊        | 37/200 [08:20<41:05, 15.13s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  19%|█▉        | 38/200 [08:33<39:11, 14.52s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  20%|█▉        | 39/200 [08:47<39:00, 14.54s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  20%|██        | 40/200 [09:00<37:08, 13.93s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  20%|██        | 41/200 [09:14<36:54, 13.93s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  21%|██        | 42/200 [09:45<50:20, 19.12s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  22%|██▏       | 43/200 [09:57<44:38, 17.06s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  22%|██▏       | 44/200 [10:20<48:32, 18.67s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  22%|██▎       | 45/200 [10:35<45:51, 17.75s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  23%|██▎       | 46/200 [10:48<42:02, 16.38s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  24%|██▎       | 47/200 [11:01<38:42, 15.18s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  24%|██▍       | 48/200 [11:12<35:24, 13.98s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  24%|██▍       | 49/200 [11:35<41:52, 16.64s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  25%|██▌       | 50/200 [11:46<37:15, 14.90s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  26%|██▌       | 51/200 [11:58<34:59, 14.09s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  26%|██▌       | 52/200 [12:11<34:18, 13.91s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  26%|██▋       | 53/200 [12:25<33:57, 13.86s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  27%|██▋       | 54/200 [12:38<33:02, 13.58s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  28%|██▊       | 55/200 [12:59<38:08, 15.78s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  28%|██▊       | 56/200 [13:07<32:15, 13.44s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  28%|██▊       | 57/200 [13:29<38:27, 16.13s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  29%|██▉       | 58/200 [13:41<35:07, 14.84s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  30%|██▉       | 59/200 [13:52<32:01, 13.63s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  30%|███       | 60/200 [14:09<34:03, 14.59s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  30%|███       | 61/200 [14:29<37:50, 16.33s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  31%|███       | 62/200 [14:40<33:57, 14.76s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  32%|███▏      | 63/200 [14:55<33:16, 14.58s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  32%|███▏      | 64/200 [15:06<31:02, 13.69s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  32%|███▎      | 65/200 [15:28<36:26, 16.19s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  33%|███▎      | 66/200 [15:39<32:19, 14.48s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  34%|███▎      | 67/200 [15:51<30:46, 13.89s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  34%|███▍      | 68/200 [16:03<29:13, 13.28s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  34%|███▍      | 69/200 [16:17<29:36, 13.56s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  35%|███▌      | 70/200 [16:41<36:04, 16.65s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  36%|███▌      | 71/200 [16:54<33:23, 15.53s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  36%|███▌      | 72/200 [17:06<31:01, 14.54s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  36%|███▋      | 73/200 [17:18<28:58, 13.69s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  37%|███▋      | 74/200 [17:31<28:21, 13.50s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  38%|███▊      | 75/200 [17:43<27:27, 13.18s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  38%|███▊      | 76/200 [17:51<23:55, 11.58s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  38%|███▊      | 77/200 [18:03<24:04, 11.74s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  39%|███▉      | 78/200 [18:14<23:19, 11.47s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  40%|███▉      | 79/200 [18:35<28:26, 14.11s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  40%|████      | 80/200 [18:50<29:06, 14.56s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  40%|████      | 81/200 [19:01<26:27, 13.34s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  41%|████      | 82/200 [19:23<31:31, 16.03s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  42%|████▏     | 83/200 [19:34<28:11, 14.46s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  42%|████▏     | 84/200 [19:55<31:44, 16.42s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  42%|████▎     | 85/200 [20:17<34:52, 18.20s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  43%|████▎     | 86/200 [20:32<32:50, 17.28s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  44%|████▎     | 87/200 [20:45<29:45, 15.80s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  44%|████▍     | 88/200 [20:57<27:36, 14.79s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  44%|████▍     | 89/200 [21:25<34:38, 18.72s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  45%|████▌     | 90/200 [21:37<30:57, 16.88s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  46%|████▌     | 91/200 [21:55<30:46, 16.94s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  46%|████▌     | 92/200 [22:02<25:37, 14.24s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  46%|████▋     | 93/200 [22:13<23:37, 13.25s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  47%|████▋     | 94/200 [22:25<22:45, 12.88s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  48%|████▊     | 95/200 [22:34<20:29, 11.71s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  48%|████▊     | 96/200 [22:48<21:10, 12.21s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  48%|████▊     | 97/200 [22:59<20:29, 11.93s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  49%|████▉     | 98/200 [23:10<19:48, 11.65s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  50%|████▉     | 99/200 [23:31<24:30, 14.56s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  50%|█████     | 100/200 [23:43<22:48, 13.68s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  50%|█████     | 101/200 [24:04<26:01, 15.77s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  51%|█████     | 102/200 [24:18<25:04, 15.35s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  52%|█████▏    | 103/200 [24:40<28:05, 17.37s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  52%|█████▏    | 104/200 [24:54<26:04, 16.29s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  52%|█████▎    | 105/200 [25:15<28:06, 17.75s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  53%|█████▎    | 106/200 [25:29<26:02, 16.62s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  54%|█████▎    | 107/200 [25:38<22:16, 14.37s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  54%|█████▍    | 108/200 [25:46<18:54, 12.33s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  55%|█████▍    | 109/200 [25:58<18:47, 12.39s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  55%|█████▌    | 110/200 [26:07<16:52, 11.25s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  56%|█████▌    | 111/200 [26:36<24:28, 16.50s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  56%|█████▌    | 112/200 [26:47<21:59, 15.00s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  56%|█████▋    | 113/200 [26:59<20:31, 14.15s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  57%|█████▋    | 114/200 [27:14<20:25, 14.25s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  57%|█████▊    | 115/200 [27:38<24:17, 17.15s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  58%|█████▊    | 116/200 [27:47<20:46, 14.84s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  58%|█████▊    | 117/200 [28:00<19:41, 14.24s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  59%|█████▉    | 118/200 [28:18<21:05, 15.44s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  60%|█████▉    | 119/200 [28:31<19:49, 14.68s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  60%|██████    | 120/200 [28:57<23:50, 17.88s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  60%|██████    | 121/200 [29:21<26:17, 19.97s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  61%|██████    | 122/200 [29:32<22:30, 17.32s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  62%|██████▏   | 123/200 [29:51<22:35, 17.60s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  62%|██████▏   | 124/200 [30:02<19:57, 15.76s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  62%|██████▎   | 125/200 [30:25<22:29, 17.99s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  63%|██████▎   | 126/200 [30:37<19:55, 16.16s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  64%|██████▎   | 127/200 [30:49<18:05, 14.87s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  64%|██████▍   | 128/200 [31:04<17:42, 14.76s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  64%|██████▍   | 129/200 [31:17<16:52, 14.26s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  65%|██████▌   | 130/200 [31:27<15:23, 13.20s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  66%|██████▌   | 131/200 [31:51<18:40, 16.23s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  66%|██████▌   | 132/200 [32:02<16:42, 14.75s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  66%|██████▋   | 133/200 [32:14<15:35, 13.96s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  67%|██████▋   | 134/200 [32:24<14:09, 12.86s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  68%|██████▊   | 135/200 [32:37<13:57, 12.89s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  68%|██████▊   | 136/200 [32:59<16:38, 15.59s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  68%|██████▊   | 137/200 [33:12<15:19, 14.59s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  69%|██████▉   | 138/200 [33:19<12:51, 12.44s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  70%|██████▉   | 139/200 [33:34<13:34, 13.35s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  70%|███████   | 140/200 [33:49<13:43, 13.72s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  70%|███████   | 141/200 [34:11<15:57, 16.23s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  71%|███████   | 142/200 [34:23<14:22, 14.87s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  72%|███████▏  | 143/200 [34:34<13:05, 13.78s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  72%|███████▏  | 144/200 [34:47<12:30, 13.41s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  72%|███████▎  | 145/200 [35:01<12:36, 13.75s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  73%|███████▎  | 146/200 [35:13<11:53, 13.21s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  74%|███████▎  | 147/200 [35:29<12:26, 14.08s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  74%|███████▍  | 148/200 [35:36<10:22, 11.97s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  74%|███████▍  | 149/200 [35:49<10:28, 12.33s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  75%|███████▌  | 150/200 [36:03<10:41, 12.83s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  76%|███████▌  | 151/200 [36:17<10:37, 13.01s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  76%|███████▌  | 152/200 [36:29<10:12, 12.77s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  76%|███████▋  | 153/200 [36:44<10:33, 13.48s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  77%|███████▋  | 154/200 [36:58<10:22, 13.53s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  78%|███████▊  | 155/200 [37:12<10:22, 13.84s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  78%|███████▊  | 156/200 [37:27<10:23, 14.16s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  78%|███████▊  | 157/200 [37:38<09:27, 13.20s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  79%|███████▉  | 158/200 [37:50<08:55, 12.76s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  80%|███████▉  | 159/200 [38:02<08:32, 12.50s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  80%|████████  | 160/200 [38:16<08:37, 12.93s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  80%|████████  | 161/200 [38:28<08:19, 12.82s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  81%|████████  | 162/200 [38:41<08:08, 12.86s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  82%|████████▏ | 163/200 [38:56<08:10, 13.25s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  82%|████████▏ | 164/200 [39:07<07:38, 12.75s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  82%|████████▎ | 165/200 [39:19<07:20, 12.57s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  83%|████████▎ | 166/200 [39:28<06:28, 11.43s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  84%|████████▎ | 167/200 [39:41<06:33, 11.92s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  84%|████████▍ | 168/200 [39:54<06:27, 12.12s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  84%|████████▍ | 169/200 [40:06<06:19, 12.24s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  85%|████████▌ | 170/200 [40:37<08:49, 17.66s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  86%|████████▌ | 171/200 [41:02<09:40, 20.01s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  86%|████████▌ | 172/200 [41:14<08:10, 17.51s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  86%|████████▋ | 173/200 [41:21<06:32, 14.53s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  87%|████████▋ | 174/200 [41:43<07:16, 16.81s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  88%|████████▊ | 175/200 [41:57<06:34, 15.76s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  88%|████████▊ | 176/200 [42:09<05:56, 14.84s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  88%|████████▊ | 177/200 [42:21<05:18, 13.83s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  89%|████████▉ | 178/200 [42:34<04:57, 13.54s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  90%|████████▉ | 179/200 [42:48<04:45, 13.61s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  90%|█████████ | 180/200 [42:59<04:20, 13.02s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  90%|█████████ | 181/200 [43:14<04:17, 13.55s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  91%|█████████ | 182/200 [43:37<04:53, 16.30s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  92%|█████████▏| 183/200 [43:50<04:23, 15.49s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  92%|█████████▏| 184/200 [44:03<03:54, 14.68s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  92%|█████████▎| 185/200 [44:21<03:52, 15.51s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  93%|█████████▎| 186/200 [44:33<03:25, 14.67s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  94%|█████████▎| 187/200 [44:44<02:55, 13.54s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  94%|█████████▍| 188/200 [44:56<02:36, 13.05s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  94%|█████████▍| 189/200 [45:26<03:20, 18.24s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  95%|█████████▌| 190/200 [45:41<02:50, 17.01s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  96%|█████████▌| 191/200 [45:48<02:07, 14.16s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  96%|█████████▌| 192/200 [46:00<01:47, 13.44s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  96%|█████████▋| 193/200 [46:11<01:29, 12.83s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  97%|█████████▋| 194/200 [46:21<01:12, 12.05s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  98%|█████████▊| 195/200 [46:34<01:00, 12.07s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  98%|█████████▊| 196/200 [46:53<00:56, 14.22s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  98%|█████████▊| 197/200 [47:07<00:42, 14.08s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating:  99%|█████████▉| 198/200 [47:29<00:33, 16.62s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating: 100%|█████████▉| 199/200 [47:42<00:15, 15.53s/it]Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#
# Evaluating: 100%|██████████| 200/200 [47:57<00:00, 14.39s/it]
# ==================================================
# 🏆 نتایج نهایی ارزیابی (Semantic RAG + Few-Shot CoT) 🏆
# ==================================================
# تعداد کل نمونه‌ها: 200
# مجموع امتیازات کسب شده: 111.5
# میانگین امتیاز (Accuracy): 0.5575 یا 55.75%
# ==================================================
#
# 🔍 تحلیل خطاها (نمونه‌های با امتیاز ۰):
# ID: q-3 | Predicted: D | Golden: B
# ID: q-5 | Predicted: D | Golden: C
# ID: q-6 | Predicted: D | Golden: C
# ID: q-7 | Predicted: C | Golden: B,D
# ID: q-8 | Predicted: B | Golden: A
